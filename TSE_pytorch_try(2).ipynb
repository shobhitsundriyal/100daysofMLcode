# %% [markdown]
# <a href="https://colab.research.google.com/github/shobhitsundriyal/100daysofMLcode/blob/master/TSE_pytorch_try(2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! mkdir ~/.kaggle
! cp kaggle.json ~/.kaggle/
! chmod 600 ~/.kaggle/kaggle.json
! kaggle competitions download -c "tweet-sentiment-extraction"
# !unzip 'train.csv.zip'
# Out:
# ...
#   0% 0.00/1.23M [00:00<?, ?B/s]
# 100% 1.23M/1.23M [00:00<00:00, 85.6MB/s]
# ...
#   0% 0.00/307k [00:00<?, ?B/s]
# 100% 307k/307k [00:00<00:00, 99.1MB/s]
# ...
#   0% 0.00/41.4k [00:00<?, ?B/s]
# 100% 41.4k/41.4k [00:00<00:00, 36.9MB/s]
# Archive:  train.csv.zip
#   inflating: train.csv

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.functional as F

# %%
train_df = pd.read_csv('train.csv')
test_df = pd.read_csv('test.csv')
train_df.head()
# Out:
#        textID  ... sentiment
# 0  cb774db0d1  ...   neutral
# 1  549e992a42  ...  negative
# 2  088c60f138  ...  negative
# 3  9642c003ef  ...  negative
# 4  358bd9e861  ...  negative
#
# [5 rows x 4 columns]
